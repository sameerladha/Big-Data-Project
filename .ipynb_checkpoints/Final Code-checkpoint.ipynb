# %% [markdown]
# **Final Code for Big Data Project**
#
# This document will contain the final versions of the code for the project with changes and errors corrected.

# %%
import pandas as pd
from patsy import dmatrices
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.discrete.discrete_model as sm
from sklearn import preprocessing

df = pd.read_csv('wpmhdata.csv', sep=',')
df = df.iloc[: , 1:-5]

# %% [markdown]
# **Examining the Data imported from R after preparation**
#
# This section of the code will review the data imported from R after the preprocessing has been done. The method utilized in R allowed for greater flexibility in preparation whereas Python allowed for a more streamlined apporach to the analysis.

# %%
#Looking at the first 10 results of the data to ensure they match the R output
df.head(10)
# Out:
#      no_Employees  tech_nontech      benefits employer_resources  \
# 0          26-100           1.0           NaN                 No
# 1            6-25           1.0            No                Yes
# 2            6-25           1.0            No                 No
# 3             NaN           NaN           NaN                NaN
# 4            6-25           0.0           Yes                 No
# 5  More than 1000           1.0           Yes                 No
# 6          26-100           1.0  I don't know                 No
# 7  More than 1000           1.0           Yes                 No
# 8          26-100           0.0  I don't know                 No
# 9             NaN           NaN           NaN                NaN
#
#   anonymity_protected                       leave discussing_mh_negative  \
# 0        I don't know                   Very easy                     No
# 1                 Yes               Somewhat easy                     No
# 2        I don't know  Neither easy nor difficult                  Maybe
# 3                 NaN                         NaN                    NaN
# 4                  No  Neither easy nor difficult                    Yes
# 5                 Yes               Somewhat easy                    Yes
# 6        I don't know               Somewhat easy                     No
# 7                 Yes                   Very easy                     No
# 8        I don't know                         NaN                    Yes
# 9                 NaN                         NaN                    NaN
#
#   discussing_ph_negative comfortable_coworker comfortable_supervisor  ...  \
# 0                     No                Maybe                    Yes  ...
# 1                     No                Maybe                    Yes  ...
# 2                     No                Maybe                  Maybe  ...
# 3                    NaN                  NaN                    NaN  ...
# 4                  Maybe                Maybe                     No  ...
# 5                    Yes                Maybe                    Yes  ...
# 6                     No                Maybe                    Yes  ...
# 7                     No                Maybe                    Yes  ...
# 8                    Yes                  Yes                  Maybe  ...
# 9                    NaN                  NaN                    NaN  ...
#
#         share_ff bad_response_experience see_others_reveal current_disorder  \
# 0  Somewhat open                      No               NaN               No
# 1  Somewhat open                      No               NaN              Yes
# 2  Somewhat open          Maybe/Not sure               Yes               No
# 3        Neutral                      No               NaN              Yes
# 4  Somewhat open      Yes, I experienced               Yes              Yes
# 5  Somewhat open      Yes, I experienced                No              Yes
# 6            NaN                      No               NaN               No
# 7  Somewhat open         Yes, I observed             Maybe              Yes
# 8  Somewhat open         Yes, I observed                No              Yes
# 9      Very open                      No               NaN              Yes
#
#   diagnosed treatment interfere_treated interferes_not_treated   age     sex
# 0       Yes         0               NaN                    NaN  39.0    Male
# 1       Yes         1            Rarely              Sometimes  29.0    Male
# 2        No         1               NaN                    NaN  38.0    Male
# 3       Yes         1         Sometimes              Sometimes  43.0    Male
# 4       Yes         1         Sometimes              Sometimes  43.0  Female
# 5        No         1               NaN                  Often  42.0    Male
# 6        No         0               NaN                    NaN  30.0    Male
# 7       Yes         1         Sometimes                  Often  37.0  Female
# 8       Yes         1            Rarely                  Often  44.0  Female
# 9       Yes         1            Rarely                  Often  30.0    Male
#
# [10 rows x 26 columns]

# %%
# look at meta information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   no_Employees                  1146 non-null   object
#  1   tech_nontech                  1146 non-null   float64
#  2   benefits                      1063 non-null   object
#  3   employer_resources            1146 non-null   object
#  4   anonymity_protected           1146 non-null   object
#  5   leave                         878 non-null    object
#  6   discussing_mh_negative        1146 non-null   object
#  7   discussing_ph_negative        1146 non-null   object
#  8   comfortable_coworker          1146 non-null   object
#  9   comfortable_supervisor        1146 non-null   object
#  10  physical_serious              653 non-null    object
#  11  consequences_discussed        1146 non-null   object
#  12  productivity_affected         256 non-null    object
#  13  amount_productivity_affected  204 non-null    object
#  14  identifing_career             1433 non-null   object
#  15  coworker_negative_view        1433 non-null   object
#  16  share_ff                      1321 non-null   object
#  17  bad_response_experience       1344 non-null   object
#  18  see_others_reveal             657 non-null    object
#  19  current_disorder              1433 non-null   object
#  20  diagnosed                     1433 non-null   object
#  21  treatment                     1433 non-null   int64
#  22  interfere_treated             876 non-null    object
#  23  interferes_not_treated        965 non-null    object
#  24  age                           1428 non-null   float64
#  25  sex                           1422 non-null   object
# dtypes: float64(2), int64(1), object(23)
# memory usage: 291.2+ KB

# %% [markdown]
# **Recoding Values in order to accurately conduct Naive Bayes and Decision Tree algorithms**
#
# This section of the code will recode and prepare the data in the python environemnt to be analysed by the required algorithms

# %%
#This variable lists all the categorical variables 

cat_cols=["sex","sex","tech_nontech","no_Employees","benefits","employer_resources","anonymity_protected","leave","discussing_mh_negative","discussing_ph_negative","comfortable_coworker", "comfortable_supervisor","physical_serious", "consequences_discussed","productivity_affected","amount_productivity_affected","identifing_career","coworker_negative_view",
          "share_ff","bad_response_experience","see_others_reveal","current_disorder","diagnosed","treatment","interfere_treated","interferes_not_treated"]

# %%
df_onehot=df.copy()

#convert only categorical variables/features to dummy/one-hot features
df_onehot = pd.get_dummies(df, columns=cat_cols, prefix = cat_cols)
df_onehot = df_onehot.iloc[:,4:]

df_onehot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 85 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   sex_Female                                           1433 non-null   uint8
#  1   sex_Male                                             1433 non-null   uint8
#  2   sex_Non-Binary                                       1433 non-null   uint8
#  3   sex_Other Gender Identity                            1433 non-null   uint8
#  4   tech_nontech_0.0                                     1433 non-null   uint8
#  5   tech_nontech_1.0                                     1433 non-null   uint8
#  6   no_Employees_1-5                                     1433 non-null   uint8
#  7   no_Employees_100-500                                 1433 non-null   uint8
#  8   no_Employees_26-100                                  1433 non-null   uint8
#  9   no_Employees_500-1000                                1433 non-null   uint8
#  10  no_Employees_6-25                                    1433 non-null   uint8
#  11  no_Employees_More than 1000                          1433 non-null   uint8
#  12  benefits_I don't know                                1433 non-null   uint8
#  13  benefits_No                                          1433 non-null   uint8
#  14  benefits_Yes                                         1433 non-null   uint8
#  15  employer_resources_I don't know                      1433 non-null   uint8
#  16  employer_resources_No                                1433 non-null   uint8
#  17  employer_resources_Yes                               1433 non-null   uint8
#  18  anonymity_protected_I don't know                     1433 non-null   uint8
#  19  anonymity_protected_No                               1433 non-null   uint8
#  20  anonymity_protected_Yes                              1433 non-null   uint8
#  21  leave_Neither easy nor difficult                     1433 non-null   uint8
#  22  leave_Somewhat difficult                             1433 non-null   uint8
#  23  leave_Somewhat easy                                  1433 non-null   uint8
#  24  leave_Very easy                                      1433 non-null   uint8
#  25  discussing_mh_negative_Maybe                         1433 non-null   uint8
#  26  discussing_mh_negative_No                            1433 non-null   uint8
#  27  discussing_mh_negative_Yes                           1433 non-null   uint8
#  28  discussing_ph_negative_Maybe                         1433 non-null   uint8
#  29  discussing_ph_negative_No                            1433 non-null   uint8
#  30  discussing_ph_negative_Yes                           1433 non-null   uint8
#  31  comfortable_coworker_Maybe                           1433 non-null   uint8
#  32  comfortable_coworker_No                              1433 non-null   uint8
#  33  comfortable_coworker_Yes                             1433 non-null   uint8
#  34  comfortable_supervisor_Maybe                         1433 non-null   uint8
#  35  comfortable_supervisor_No                            1433 non-null   uint8
#  36  comfortable_supervisor_Yes                           1433 non-null   uint8
#  37  physical_serious_No                                  1433 non-null   uint8
#  38  physical_serious_Yes                                 1433 non-null   uint8
#  39  consequences_discussed_No                            1433 non-null   uint8
#  40  consequences_discussed_Yes                           1433 non-null   uint8
#  41  productivity_affected_No                             1433 non-null   uint8
#  42  productivity_affected_Unsure                         1433 non-null   uint8
#  43  productivity_affected_Yes                            1433 non-null   uint8
#  44  amount_productivity_affected_1-25%                   1433 non-null   uint8
#  45  amount_productivity_affected_26-50%                  1433 non-null   uint8
#  46  amount_productivity_affected_51-75%                  1433 non-null   uint8
#  47  amount_productivity_affected_76-100%                 1433 non-null   uint8
#  48  identifing_career_Maybe                              1433 non-null   uint8
#  49  identifing_career_No, I don't think it would         1433 non-null   uint8
#  50  identifing_career_No, it has not                     1433 non-null   uint8
#  51  identifing_career_Yes, I think it would              1433 non-null   uint8
#  52  identifing_career_Yes, it has                        1433 non-null   uint8
#  53  coworker_negative_view_Maybe                         1433 non-null   uint8
#  54  coworker_negative_view_No, I don't think they would  1433 non-null   uint8
#  55  coworker_negative_view_No, they do not               1433 non-null   uint8
#  56  coworker_negative_view_Yes, I think they would       1433 non-null   uint8
#  57  coworker_negative_view_Yes, they do                  1433 non-null   uint8
#  58  share_ff_Neutral                                     1433 non-null   uint8
#  59  share_ff_Not open at all                             1433 non-null   uint8
#  60  share_ff_Somewhat not open                           1433 non-null   uint8
#  61  share_ff_Somewhat open                               1433 non-null   uint8
#  62  share_ff_Very open                                   1433 non-null   uint8
#  63  bad_response_experience_Maybe/Not sure               1433 non-null   uint8
#  64  bad_response_experience_No                           1433 non-null   uint8
#  65  bad_response_experience_Yes, I experienced           1433 non-null   uint8
#  66  bad_response_experience_Yes, I observed              1433 non-null   uint8
#  67  see_others_reveal_Maybe                              1433 non-null   uint8
#  68  see_others_reveal_No                                 1433 non-null   uint8
#  69  see_others_reveal_Yes                                1433 non-null   uint8
#  70  current_disorder_Maybe                               1433 non-null   uint8
#  71  current_disorder_No                                  1433 non-null   uint8
#  72  current_disorder_Yes                                 1433 non-null   uint8
#  73  diagnosed_No                                         1433 non-null   uint8
#  74  diagnosed_Yes                                        1433 non-null   uint8
#  75  treatment_0                                          1433 non-null   uint8
#  76  treatment_1                                          1433 non-null   uint8
#  77  interfere_treated_Never                              1433 non-null   uint8
#  78  interfere_treated_Often                              1433 non-null   uint8
#  79  interfere_treated_Rarely                             1433 non-null   uint8
#  80  interfere_treated_Sometimes                          1433 non-null   uint8
#  81  interferes_not_treated_Never                         1433 non-null   uint8
#  82  interferes_not_treated_Often                         1433 non-null   uint8
#  83  interferes_not_treated_Rarely                        1433 non-null   uint8
#  84  interferes_not_treated_Sometimes                     1433 non-null   uint8
# dtypes: uint8(85)
# memory usage: 119.1 KB

# %%
from sklearn.model_selection import train_test_split

class_col_name="employer_resources_No"

one_hot_feature_names=df_onehot.columns[df_onehot.columns != class_col_name]

# Split dataset into training set and test set
X = list(set(list(df_onehot)) - set([class_col_name]))

X_train, X_test, y_train, y_test = train_test_split(df_onehot[X], df_onehot[class_col_name], test_size=0.4,random_state=0) # 60% training and 40% test

# %% [markdown]
# **Naive Bayes Algorithm**

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()

#Train the model using the training sets
nbfit = nb.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = nbfit.predict(X_test)

# %%
#This section will check the number of features and records to ensure they match with our original data set and that all records are analyzed appropriately

print("Number of features used ",nbfit.n_features_in_)
print("Classes ",nbfit.classes_)
print("Number of records for classes ",nbfit.class_count_)
# Out:
# Number of features used  84
# Classes  [0 1]
# Number of records for classes  [372. 487.]

# %% [markdown]
# **Evaluation of Naive Bayes**
#
# In this section, I will evaluate the Naive Bayes model using a confusion matrix. This will allow me to determine if the data from this model is useful and provides relevant insights.

# %%
from sklearn.metrics import confusion_matrix

cf=confusion_matrix(y_test, y_pred)
print ("Confusion Matrix")
print(cf)
tn, fp, fn, tp=cf.ravel()
print ("TP: ", tp,", FP: ", fp,", TN: ", tn,", FN:", fn)
# Out:
# Confusion Matrix
# [[242   6]
#  [  6 320]]
# TP:  320 , FP:  6 , TN:  242 , FN: 6

# %%
from sklearn.metrics import classification_report
from sklearn import metrics

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       248
#            1       0.98      0.98      0.98       326
#
#     accuracy                           0.98       574
#    macro avg       0.98      0.98      0.98       574
# weighted avg       0.98      0.98      0.98       574

# %% [markdown]
# **Perform K-fold Cross Validation on the Naive Bayes model**

# %%
from sklearn.model_selection import KFold, cross_val_score 
k_folds = KFold(n_splits = 10)

scores = cross_val_score(nbfit, X_test, y_test, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.9137931  0.94827586 0.94827586 0.93103448 0.94736842 0.84210526
#  0.96491228 0.89473684 0.94736842 0.98245614]
# Average CV Score:  0.932032667876588
# Number of CV Scores used in Average:  10

# %% [markdown]
# **Logisitic Regression with Cross Validation**
#
# This section will utilize the logisitic regression with cross validation algorithim from sklearn to analyze the data.

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn import metrics
from sklearn.metrics import accuracy_score

logreg = LogisticRegressionCV(cv = 10)
logreg = logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

# %%
print ('Logistic Regression Confusion Matrix')
predLR = y_pred > 0.5
actualLR = y_test > 0.5
LRcm = confusion_matrix(actualLR, predLR)
print(LRcm)
# Out:
# Logistic Regression Confusion Matrix
# [[248   0]
#  [  0 326]]

# %%
print('Accuracy: Logisitic Regression')
LRaccuracy = float((LRcm[0][0] + LRcm[1][1]))/float(len(actualLR))
print(LRaccuracy)
print ()

print('Precision: Logisitic Regression')
LRprecision = float(LRcm[0][0]/(LRcm[1][0] + LRcm[0][0]))
print(LRprecision)
print()

print('Recall: Logisitic Regression')
LRrecall = float(LRcm[0][0]/(LRcm[0][0] + LRcm[0][1]))
print(LRrecall)
print()
# Out:
# Accuracy: Logisitic Regression
# 1.0
#
# Precision: Logisitic Regression
# 1.0
#
# Recall: Logisitic Regression
# 1.0

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

model = RandomForestClassifier(max_depth=2)
model = model.fit(X_train, y_train)
print('Training Accuracy : ',
      metrics.accuracy_score(y_train,
                             model.predict(X_train))*100)
print('Validation Accuracy : ',
      metrics.accuracy_score(y_test,
                             model.predict(X_test))*100)
# Out:
# Training Accuracy :  81.49010477299186
# Validation Accuracy :  79.44250871080139

# %% [markdown]
# **Visualize a tree from the Randomforest function**

# %%
from sklearn import tree
import graphviz
dot_data = tree.export_graphviz(model.estimators_[0],feature_names=one_hot_feature_names)

graph = graphviz.Source(dot_data, format="png") 
graph

# %% [markdown]
# **Perform K-fold Cross Validation on the random forest model**

# %%
from sklearn.model_selection import KFold, cross_val_score 
k_folds = KFold(n_splits = 10)

scores = cross_val_score(model, X_test, y_test, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.93103448 0.84482759 0.82758621 0.84482759 0.84210526 0.80701754
#  0.85964912 0.75438596 0.89473684 0.85964912]
# Average CV Score:  0.8465819721718087
# Number of CV Scores used in Average:  10

# %% [markdown]
# **Spearman Correlation Matrix**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_sp = df_onehot.copy()

corrtry = df_sp.corr(method="spearman")[['benefits_Yes','benefits_No','employer_resources_Yes','employer_resources_No', 'anonymity_protected_No', 'anonymity_protected_Yes', 'current_disorder_Yes']]

fig, ax = plt.subplots(figsize=(10,30))

hm = sns.heatmap(corrtry, annot = True, ax=ax, cmap='BrBG')
hm_fig = hm.get_figure()
hm_fig.savefig('Spearman Correlation Heatmap.png')
plt.show(hm)
